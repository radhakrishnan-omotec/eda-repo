# %% [markdown]
# <a href="https://colab.research.google.com/github/radhakrishnan-omotec/eda-repo/blob/main/EDA_Eklavea_Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Setup

# %%
# !git clone https://github.com/radhakrishnan-omotec/eda-repo.git
# Out:
# Cloning into 'eda-repo'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 21 (delta 5), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (21/21), 7.52 MiB | 30.94 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %% [markdown]
# ### 1) Importing the necessary python libraries

# %%
import pandas as pd

# %% [markdown]
# Readint the CSV file

# %%
input_df = pd.read_csv("/content/eda-repo/EDA_Dataset- Input-Responses.csv")
input_df.head()
# Out:
#    S.No Age_group                  Q1                                Q2  \
# 0     1   45 - 54       Self-employed  Internal Combustion (IC) vehicle
# 1     2   35 - 44       Self-employed  Internal Combustion (IC) vehicle
# 2     3   55 - 64       Self-employed  Internal Combustion (IC) vehicle
# 3     4   55 - 64       Self-employed                         Bike/Walk
# 4     5   55 - 64  Employed full-time                         Bike/Walk
#
#                   Q3                                                 Q4  \
# 0  Somewhat unlikely  Availability of charging stations, Lack of inf...
# 1    Somewhat likely                                        Cost of EVs
# 2    Somewhat likely  Availability of charging stations, Lack of inf...
# 3            Neutral  Availability of charging stations, Environment...
# 4        Very likely                  Availability of charging stations
#
#            Q5                                   Q6     Q7  \
# 0  Fewer jobs                Public transportation     No
# 1  Fewer jobs  Battery manufacturing and recycling  Maybe
# 2      Unsure                          Oil and gas     No
# 3      Unsure                          Oil and gas  Maybe
# 4      Unsure           Automotive manufacturing,      No
#
#                              Q8                                        Q9
# 0                          Nope                                   No idea
# 1  Takes a long time to charge   As per the need changes need to be made
# 2                            No                                  Not sure
# 3                           No                                 Awareness
# 4                            No                            Time will tell
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['S.No'].plot(kind='hist', bins=20, title='S.No')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Age_group').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('Q1').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('Q2').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('Q3').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['S.No']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'S.No'}, axis=1)
#               .sort_values('S.No', ascending=True))
#   xs = counted['S.No']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_5.sort_values('S.No', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Age_group')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Age_group', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('S.No')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['S.No']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'S.No'}, axis=1)
#               .sort_values('S.No', ascending=True))
#   xs = counted['S.No']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_6.sort_values('S.No', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Q1')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Q1', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('S.No')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['S.No']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'S.No'}, axis=1)
#               .sort_values('S.No', ascending=True))
#   xs = counted['S.No']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_7.sort_values('S.No', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Q2')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Q2', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('S.No')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['S.No']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'S.No'}, axis=1)
#               .sort_values('S.No', ascending=True))
#   xs = counted['S.No']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('S.No', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Q3')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Q3', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('S.No')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_9['S.No'].plot(kind='line', figsize=(8, 4), title='S.No')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Q1'].value_counts()
#     for x_label, grp in _df_10.groupby('Age_group')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Age_group')
# _ = plt.ylabel('Q1')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Q2'].value_counts()
#     for x_label, grp in _df_11.groupby('Q1')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Q1')
# _ = plt.ylabel('Q2')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Q3'].value_counts()
#     for x_label, grp in _df_12.groupby('Q2')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Q2')
# _ = plt.ylabel('Q3')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Q4'].value_counts()
#     for x_label, grp in _df_13.groupby('Q3')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Q3')
# _ = plt.ylabel('Q4')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_14['Age_group'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_14, x='S.No', y='Age_group', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_15['Q1'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_15, x='S.No', y='Q1', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_16['Q2'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_16, x='S.No', y='Q2', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_17['Q3'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_17, x='S.No', y='Q3', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_Q1 = LabelEncoder()
le_Q2 = LabelEncoder()
le_Q3 = LabelEncoder()
le_Q4 = LabelEncoder()
le_Q5 = LabelEncoder()
le_Q6 = LabelEncoder()
le_Q7 = LabelEncoder()
le_Q8 = LabelEncoder()
le_Q9 = LabelEncoder()

# %%
input_df['Q1_new'] = le_Q1.fit_transform(input_df['Q1'])
input_df['Q2_new'] = le_Q2.fit_transform(input_df['Q2'])
input_df['Q3_new'] = le_Q3.fit_transform(input_df['Q3'])
input_df['Q4_new'] = le_Q4.fit_transform(input_df['Q4'])
input_df['Q5_new'] = le_Q5.fit_transform(input_df['Q5'])
input_df['Q6_new'] = le_Q6.fit_transform(input_df['Q6'])
input_df['Q7_new'] = le_Q7.fit_transform(input_df['Q7'])
input_df['Q8_new'] = le_Q8.fit_transform(input_df['Q8'])
input_df['Q9_new'] = le_Q9.fit_transform(input_df['Q9'])

# %%
input_df.head(50)
# Out:
#     S.No     Age_group                  Q1                                Q2  \
# 0      1       45 - 54       Self-employed  Internal Combustion (IC) vehicle
# 1      2       35 - 44       Self-employed  Internal Combustion (IC) vehicle
# 2      3       55 - 64       Self-employed  Internal Combustion (IC) vehicle
# 3      4       55 - 64       Self-employed                         Bike/Walk
# 4      5       55 - 64  Employed full-time                         Bike/Walk
# 5      6       35 - 44  Employed full-time  Internal Combustion (IC) vehicle
# 6      7       55 - 64             Retired  Internal Combustion (IC) vehicle
# 7      8  65 and above             Retired  Internal Combustion (IC) vehicle
# 8      9       45 - 54       Self-employed  Internal Combustion (IC) vehicle
# 9     10       35 - 44       Self-employed             Electric Vehicle (EV)
# 10    11  65 and above             Retired  Internal Combustion (IC) vehicle
# 11    12       18 - 24  Employed part-time             Public transportation
# 12    13       45 - 54  Employed full-time  Internal Combustion (IC) vehicle
# 13    14      Under 18             Student                        School bus
# 14    15       45 - 54       Self-employed                               Car
# 15    16       35 - 44  Employed full-time                         Bike/Walk
# 16    17       45 - 54       Self-employed  Internal Combustion (IC) vehicle
# 17    18       55 - 64       Self-employed  Internal Combustion (IC) vehicle
# 18    19       25 - 34  Employed full-time             Electric Vehicle (EV)
# 19    20       35 - 44       Self-employed  Internal Combustion (IC) vehicle
# 20    21       45 - 54       Self-employed             Electric Vehicle (EV)
# 21    22       45 - 54       Self-employed  Internal Combustion (IC) vehicle
# 22    23       45 - 54       Self-employed             Public transportation
# 23    24       45 - 54       Self-employed  Internal Combustion (IC) vehicle
# 24    25  65 and above       Self-employed  Internal Combustion (IC) vehicle
# 25    26       45 - 54  Employed full-time             Public transportation
# 26    27       45 - 54       Self-employed                         Bike/Walk
# 27    28       35 - 44       Self-employed  Internal Combustion (IC) vehicle
# 28    29       45 - 54       Self-employed                              Car
# 29    30       45 - 54       Self-employed  Internal Combustion (IC) vehicle
# 30    31       45 - 54       Self-employed  Internal Combustion (IC) vehicle
# 31    32       45 - 54       Self-employed  Internal Combustion (IC) vehicle
# 32    33       45 - 54  Employed full-time             Public transportation
# 33    34       45 - 54             Retired  Internal Combustion (IC) vehicle
# 34    35       45 - 54       Self-employed                         Bike/Walk
# 35    36       45 - 54       Self-employed  Internal Combustion (IC) vehicle
# 36    37       35 - 44       Self-employed  Internal Combustion (IC) vehicle
# 37    38       25 - 34       Self-employed  Internal Combustion (IC) vehicle
# 38    39       55 - 64             Retired             Electric Vehicle (EV)
# 39    40       55 - 64       Self-employed  Internal Combustion (IC) vehicle
# 40    41       45 - 54       Self-employed  Internal Combustion (IC) vehicle
# 41    42       45 - 54  Employed full-time                         Bike/Walk
# 42    43       55 - 64          Unemployed             Public transportation
# 43    44       55 - 64  Employed part-time                               Car
# 44    45      Under 18             Student                         Bike/Walk
# 45    46       18 - 24  Employed full-time             Public transportation
# 46    47      Under 18             Student             Electric Vehicle (EV)
# 47    48       45 - 54       Self-employed  Internal Combustion (IC) vehicle
# 48    49       45 - 54       Self-employed                  Private vehicle
# 49    50       25 - 34  Employed full-time             Public transportation
#
#                    Q3                                                 Q4  \
# 0   Somewhat unlikely  Availability of charging stations, Lack of inf...
# 1     Somewhat likely                                        Cost of EVs
# 2     Somewhat likely  Availability of charging stations, Lack of inf...
# 3             Neutral  Availability of charging stations, Environment...
# 4         Very likely                  Availability of charging stations
# 5     Somewhat likely                                        Cost of EVs
# 6             Neutral     Cost of EVs, Availability of charging stations
# 7       Very unlikely  Cost of EVs, Availability of charging stations...
# 8   Somewhat unlikely  Cost of EVs, Availability of charging stations...
# 9         Very likely  Cost of EVs, Range per charge, Environmental i...
# 10    Somewhat likely                               Environmental impact
# 11      Very unlikely     Cost of EVs, Availability of charging stations
# 12  Somewhat unlikely                                        Cost of EVs
# 13            Neutral                               Environmental impact
# 14            Neutral                                        No concerns
# 15      Very unlikely                                        Cost of EVs
# 16            Neutral  Cost of EVs, Availability of charging stations...
# 17    Somewhat likely                  Availability of charging stations
# 18        Very likely  Cost of EVs, Availability of charging stations...
# 19  Somewhat unlikely                  Availability of charging stations
# 20        Very likely                                        No concerns
# 21            Neutral     Cost of EVs, Availability of charging stations
# 22  Somewhat unlikely     Cost of EVs, Availability of charging stations
# 23      Very unlikely                      Cost of EVs, Range per charge
# 24        Very likely                  Availability of charging stations
# 25    Somewhat likely  Cost of EVs, Availability of charging stations...
# 26      Very unlikely  Cost of EVs, Lack of information, There no any...
# 27    Somewhat likely  Cost of EVs, Availability of charging stations...
# 28      Very unlikely                   Lack of information, No concerns
# 29        Very likely                                        No concerns
# 30  Somewhat unlikely  Cost of EVs, Availability of charging stations...
# 31    Somewhat likely  Availability of charging stations, Range per c...
# 32            Neutral                               Environmental impact
# 33    Somewhat likely  Availability of charging stations, Range per c...
# 34            Neutral                  Availability of charging stations
# 35    Somewhat likely             Range per charge, Environmental impact
# 36            Neutral                  Availability of charging stations
# 37        Very likely  Cost of EVs, Range per charge, Lack of informa...
# 38        Very likely                               Environmental impact
# 39    Somewhat likely  Availability of charging stations, Lack of inf...
# 40        Very likely                                        Cost of EVs
# 41            Neutral  Cost of EVs, Availability of charging stations...
# 42    Somewhat likely  Availability of charging stations, Range per c...
# 43    Somewhat likely                  Availability of charging stations
# 44    Somewhat likely  Cost of EVs, Availability of charging stations...
# 45            Neutral                  Availability of charging stations
# 46        Very likely  Availability of charging stations, Environment...
# 47            Neutral                  Availability of charging stations
# 48            Neutral  Availability of charging stations, Range per c...
# 49    Somewhat likely  Availability of charging stations, Environment...
#
#                   Q5                                                 Q6  \
# 0         Fewer jobs                              Public transportation
# 1         Fewer jobs                Battery manufacturing and recycling
# 2             Unsure                                        Oil and gas
# 3             Unsure                                        Oil and gas
# 4             Unsure                         Automotive manufacturing,
# 5         Fewer jobs  Automotive manufacturing, Battery manufacturin...
# 6          No impact                           Automotive manufacturing
# 7             Unsure  Automotive manufacturing, Oil and gas, Public ...
# 8          No impact                                        Oil and gas
# 9   Create more jobs  Automotive manufacturing, Renewable energy (e....
# 10        Fewer jobs                                        Oil and gas
# 11            Unsure                                        Oil and gas
# 12         No impact                                        Oil and gas
# 13            Unsure   Oil and gas, Battery manufacturing and recycling
# 14            Unsure                                        Oil and gas
# 15        Fewer jobs                              Public transportation
# 16  Create more jobs    Automotive manufacturing, Public transportation
# 17  Create more jobs                                        Oil and gas
# 18            Unsure               Renewable energy (e.g., wind, solar)
# 19         No impact                 Oil and gas, Public transportation
# 20         No impact  Automotive manufacturing, Oil and gas, Battery...
# 21         No impact  Oil and gas, Renewable energy (e.g., wind, sol...
# 22        Fewer jobs                                        Oil and gas
# 23         No impact  Automotive manufacturing, Battery manufacturin...
# 24  Create more jobs                                        Oil and gas
# 25            Unsure                              Public transportation
# 26         No impact               Renewable energy (e.g., wind, solar)
# 27        Fewer jobs                                        Oil and gas
# 28            Unsure  Renewable energy (e.g., wind, solar), Battery ...
# 29            Unsure  Automotive manufacturing, Oil and gas, Renewab...
# 30            Unsure                                    Oil and gas, Hu
# 31            Unsure  Automotive manufacturing, Oil and gas, Battery...
# 32            Unsure  Automotive manufacturing, Renewable energy (e....
# 33            Unsure  Automotive manufacturing, Oil and gas, Battery...
# 34  Create more jobs                Battery manufacturing and recycling
# 35            Unsure                 Oil and gas, Public transportation
# 36            Unsure                                        Oil and gas
# 37  Create more jobs  Automotive manufacturing, Oil and gas, Battery...
# 38  Create more jobs                              Public transportation
# 39            Unsure                                        Oil and gas
# 40  Create more jobs  Automotive manufacturing, Oil and gas, Renewab...
# 41        Fewer jobs  Automotive manufacturing, Battery manufacturin...
# 42  Create more jobs  Oil and gas, Renewable energy (e.g., wind, sol...
# 43            Unsure                                        Oil and gas
# 44            Unsure                 Oil and gas, Public transportation
# 45  Create more jobs                                        Oil and gas
# 46        Fewer jobs                Battery manufacturing and recycling
# 47        Fewer jobs                                        Oil and gas
# 48  Create more jobs  Automotive manufacturing, Oil and gas, Battery...
# 49        Fewer jobs  Oil and gas, Battery manufacturing and recycli...
#
#        Q7                                                 Q8  \
# 0      No                                               Nope
# 1   Maybe                       Takes a long time to charge
# 2      No                                                 No
# 3   Maybe                                                No
# 4      No                                                 No
# 5     Yes                                                 No
# 6      No  If price become affordable and numbers of char...
# 7   Maybe                                                 No
# 8     Yes  Charging stations will be a key for transition...
# 9     Yes  We need more and more charging stations and th...
# 10     No                                 Charging stations
# 11    Yes            We will need more stations for charging
# 12     No                Cost is the major and battery life
# 13  Maybe  Safety of vehicles as there are many cases whe...
# 14     No                                        No comment
# 15  Maybe                                               Cost
# 16  Maybe                                                 No
# 17    Yes  Battery should be of proper standards...else i...
# 18  Maybe                                                 No
# 19  Maybe                                   It’s ones choice
# 20  Maybe                                                 No
# 21    Yes  Have heard that there is a blast if it’s overc...
# 22     No  Charging points to be increased. Government ta...
# 23  Maybe                                 Long tearm savings
# 24    Yes                                                 No
# 25    Yes                                                NaN
# 26     No                                        No any idea
# 27    Yes  More time taken to charge vehicle is also a co...
# 28     No                                                No
# 29     No                                                 No
# 30     No  It should be cost effective and battery capaci...
# 31    Yes  The road conditions to ge compatible with the ...
# 32  Maybe                                                 No
# 33    Yes                                                NaN
# 34     No                                                 No
# 35  Maybe     Im looking forward for hydrogen operating cars
# 36     No                                                 No
# 37    Yes                                                No
# 38    Yes                                                 No
# 39  Maybe  The only concern is how to manage travelling l...
# 40    Yes  After china indian people useing more ev bile ...
# 41    Yes                                                 No
# 42    Yes                                                 No
# 43  Maybe                                                NaN
# 44  Maybe              It will lot of time to educate people
# 45    Yes                                               Nope
# 46    Yes  Manufacture of ev  batteries have detrimental ...
# 47     No  The main concern is the availability of chargi...
# 48     No                                                  -
# 49    Yes                       There is no knowledge abt it
#
#                                                    Q9  Q1_new  Q2_new  Q3_new  \
# 0                                             No idea       3       4       2
# 1            As per the need changes need to be made        3       4       1
# 2                                            Not sure       3       4       1
# 3                                          Awareness        3       0       0
# 4                                      Time will tell       0       0       3
# 5                   There will be no negative impact        0       4       1
# 6                                          It depends       2       4       0
# 7                                     Affordability.        2       4       4
# 8   Improving skills in the field of EV’s of the c...       3       4       2
# 9   There won't be negative impact and newer jobs ...       3       3       3
# 10                                  Skill the labours       2       4       1
# 11                                Skill the labourers       1       6       4
# 12                   Awareness about the environment        0       4       2
# 13                                   Create awareness       4       7       0
# 14                                        No comment        3       1       0
# 15                                     Educate people       0       0       4
# 16  To make more awareness among the new entrants ...       3       4       0
# 17                      Proper steps should be taken.       3       4       1
# 18                                           Nothing        0       3       3
# 19  Both the types of vehicles need to be promoted...       3       4       2
# 20                            More information needed       3       3       3
# 21                                Can’t think of any        3       4       0
# 22                                                 No       3       6       2
# 23                                                 No       3       4       4
# 24                          Fire or blast in battery        3       4       3
# 25                                              Plan        0       6       1
# 26  If ev vehicle helps to environment I will be h...       3       0       4
# 27  Training to employees currently working at IC ...       3       4       1
# 28                                                No        3       2       4
# 29                                         No answer        3       4       3
# 30                                       No comments        3       4       2
# 31  Skill development for the conventional manufac...       3       4       1
# 32                                           Not sure       0       6       0
# 33  Divert available workforce into newer avenues ...       2       4       1
# 34                                                 No       3       0       0
# 35                     Not a right person to comment        3       4       1
# 36                                           No idea        3       4       0
# 37  Create additional jobs in the electric vehicle...       3       4       3
# 38                                 Positive measures        2       3       3
# 39                                         Not aware        3       4       1
# 40                                       No comments        3       4       3
# 41                                        No comments       0       0       0
# 42  To manufacture battery in India to create more...       5       6       1
# 43                                           Unaware        1       1       1
# 44                                       Skill labour       4       0       1
# 45                                  Educate awareness       0       6       0
# 46                                Awareness campaings       4       3       3
# 47  Create new jobs such as jobs related to chargi...       3       4       0
# 48                                                  -       3       5       0
# 49                        People should be made aware       0       6       1
#
#     Q4_new  Q5_new  Q6_new  Q7_new  Q8_new  Q9_new
# 0        3       1      27       1      49      53
# 1        9       1      15       0      61       2
# 2        3       3      20       1      44      59
# 3        1       3      20       0      45       3
# 4        0       3       1       1      44      88
# 5        9       1       2       2      44      84
# 6       10       2       0       1      27      41
# 7       13       3       8       0      44       1
# 8       13       2      20       2      10      37
# 9       24       0      14       2      73      85
# 10      26       1      20       1       9      78
# 11      10       3      20       2      75      77
# 12       9       2      20       1      13       4
# 13      26       3      21       0      54      12
# 14      31       3      20       1      48      50
# 15       9       1      27       0      11      21
# 16      11       0      12       0      44      90
# 17       0       0      20       2       6      71
# 18      12       3      28       0      44      62
# 19       0       2      24       0      32       8
# 20      31       2       6       0      44      45
# 21      10       2      26       2      23       9
# 22      10       1      20       1       8      47
# 23      23       2       2       0      35      47
# 24       0       0      20       2      44      26
# 25      12       3      27       2      76      67
# 26      22       2      28       1      47      35
# 27      18       1      20       2      41      93
# 28      30       3      29       1      45      48
# 29      31       3      11       1      44      49
# 30      13       3      23       1      30      52
# 31       5       3       6       2      65      74
# 32      26       3      14       0      44      59
# 33       4       3       6       2      76      18
# 34       0       0      15       1      44      47
# 35      33       3      24       0      28      55
# 36       0       3      20       1      44      54
# 37      25       0       6       2      45      11
# 38      26       0      27       2      44      68
# 39       3       3      20       0      63      57
# 40       9       0      10       2       2      52
# 41      14       1       3       2      44      51
# 42       5       0      26       2      44      91
# 43       0       3      20       0      76      95
# 44      11       3      24       0      31      75
# 45       0       0      20       2      49      19
# 46       1       1      15       2      39       6
# 47       0       1      20       1      62      15
# 48       4       0       7       1       1       0
# 49       1       1      22       2      68      66
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_18['S.No'].plot(kind='hist', bins=20, title='S.No')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['Q1_new'].plot(kind='hist', bins=20, title='Q1_new')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_20['Q2_new'].plot(kind='hist', bins=20, title='Q2_new')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_21['Q3_new'].plot(kind='hist', bins=20, title='Q3_new')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_22.groupby('Age_group').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_23.groupby('Q1').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_24.groupby('Q2').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_25.groupby('Q3').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_26.plot(kind='scatter', x='S.No', y='Q1_new', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_27.plot(kind='scatter', x='Q1_new', y='Q2_new', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_28.plot(kind='scatter', x='Q2_new', y='Q3_new', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_29.plot(kind='scatter', x='Q3_new', y='Q4_new', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['S.No']
#   ys = series['Q1_new']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_30.sort_values('S.No', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Age_group')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Age_group', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('S.No')
# _ = plt.ylabel('Q1_new')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['S.No']
#   ys = series['Q1_new']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_31.sort_values('S.No', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Q1')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Q1', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('S.No')
# _ = plt.ylabel('Q1_new')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['S.No']
#   ys = series['Q1_new']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_32.sort_values('S.No', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Q2')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Q2', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('S.No')
# _ = plt.ylabel('Q1_new')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['S.No']
#   ys = series['Q1_new']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_33.sort_values('S.No', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Q3')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Q3', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('S.No')
# _ = plt.ylabel('Q1_new')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_34['S.No'].plot(kind='line', figsize=(8, 4), title='S.No')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_35['Q1_new'].plot(kind='line', figsize=(8, 4), title='Q1_new')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_36['Q2_new'].plot(kind='line', figsize=(8, 4), title='Q2_new')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_37['Q3_new'].plot(kind='line', figsize=(8, 4), title='Q3_new')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Q1'].value_counts()
#     for x_label, grp in _df_38.groupby('Age_group')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Age_group')
# _ = plt.ylabel('Q1')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Q2'].value_counts()
#     for x_label, grp in _df_39.groupby('Q1')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Q1')
# _ = plt.ylabel('Q2')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Q3'].value_counts()
#     for x_label, grp in _df_40.groupby('Q2')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Q2')
# _ = plt.ylabel('Q3')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Q5'].value_counts()
#     for x_label, grp in _df_41.groupby('Q3')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Q3')
# _ = plt.ylabel('Q5')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_42['Age_group'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_42, x='S.No', y='Age_group', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_43['Q1'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_43, x='S.No', y='Q1', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_44['Q2'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_44, x='S.No', y='Q2', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_45['Q3'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_45, x='S.No', y='Q3', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
